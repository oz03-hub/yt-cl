# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import numpy as np
from tqdm import tqdm
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
import matplotlib.pyplot as plt
from util import save_topk_words

# %%
df = pd.read_csv("../data/transcripts_normalized.csv", header=0)
df.dropna(subset=["transcript"], inplace=True)
df.head()
# Out:
#       video_id                                         transcript
# 0  AAHiZ-c88ec  man im getting frustrated water heater deliver...
# 1  AEsRr-ZnzNc  start give shoutout rokukun vyonder harry stac...
# 2  AJpzk-aFZPU  test number alright okay oh go ground oh god c...
# 3  AONXX-h9SdI  gonna play something brand new album came octo...
# 4  AOZIY-AwsjM                                              music

# %%
def get_kmeans(tfidf: np.ndarray, n_clusters: int):
    kmeans = KMeans(n_clusters=n_clusters)
    kmeans.fit(tfidf)
    return kmeans

def get_tfidf(df: pd.DataFrame):
    tf_idf_vectorizer = TfidfVectorizer()
    tfidf_matrix = tf_idf_vectorizer.fit_transform(df["transcript"])
    return tfidf_matrix, tf_idf_vectorizer

# %%
cluster_sizes = list(range(10, 51))
measures = []
kms = []

tfidf_matrix, tfidf_vec = get_tfidf(df)

for n in tqdm(cluster_sizes):
    km = get_kmeans(tfidf_matrix, n)
    kms.append(km)
    measures.append({
            "n_clusters": n,
            "inertia": km.inertia_,
            "silhouette_score": silhouette_score(tfidf_matrix, km.labels_),
            "davies_bouldin_score": davies_bouldin_score(tfidf_matrix.toarray(), km.labels_),
            "calinski_harabasz_score": calinski_harabasz_score(tfidf_matrix.toarray(), km.labels_)
        })
# Out:
# 100%|██████████| 41/41 [02:26<00:00,  3.57s/it]

# %%
# plot measures for the same corpus, for different number of clusters
plot_attributes = ["inertia", "silhouette_score", "davies_bouldin_score", "calinski_harabasz_score"]
for attribute in plot_attributes:
    plt.figure(figsize=(10, 5))
    plt.plot(cluster_sizes, [m[attribute] for m in measures], )
    plt.title(attribute)
    plt.legend()
    plt.savefig(f"../figures/tfidf_baseline_measure_{attribute}.png")
    plt.show()

# inertia: lower better
# silhouette_score: higher better
# davies_bouldin_score: lower better
# calinski_harabasz_score: higher better
# Out:
# /var/folders/kb/q1ny0m2n19vbs1hvhhqxvp2h0000gn/T/ipykernel_11224/3523393001.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
if 'word_count' not in df.columns:
    df['word_count'] = df['transcript'].str.split().str.len()

for i in range(0, len(kms), 10):
    labels = kms[i].labels_
    n_clusters = len(set(labels))
    
    print(f"\nFor k-means with {n_clusters} clusters:")
    
    for label in range(n_clusters):
        cluster_mask = labels == label
        cluster_lengths = df[cluster_mask]['word_count']
        
        print(f"\nCluster {label}:")
        print(f"  Mean length: {cluster_lengths.mean():.1f}")
        print(f"  Median length: {cluster_lengths.median():.1f}")
        print(f"  Min length: {cluster_lengths.min()}")
        print(f"  Max length: {cluster_lengths.max()}")
        print(f"  Size: {len(cluster_lengths)} documents")
# Out:
# For k-means with 10 clusters:
#
# Cluster 0:
#   Mean length: 382.1
#   Median length: 22.5
#   Min length: 1
#   Max length: 3672
#   Size: 54 documents
#
# Cluster 1:
#   Mean length: 815.1
#   Median length: 327.0
#   Min length: 1
#   Max length: 19397
#   Size: 559 documents
#
# Cluster 2:
#   Mean length: 1651.1
#   Median length: 809.0
#   Min length: 1
#   Max length: 21641
#   Size: 236 documents
#
# Cluster 3:
#   Mean length: 122.7
#   Median length: 38.0
#   Min length: 1
#   Max length: 5182
#   Size: 189 documents
#
# Cluster 4:
#   Mean length: 147.4
#   Median length: 36.0
#   Min length: 1
#   Max length: 6191
#   Size: 1067 documents
#
# Cluster 5:
#   Mean length: 1015.2
#   Median length: 416.0
#   Min length: 1
#   Max length: 14567
#   Size: 207 documents
#
# Cluster 6:
#   Mean length: 396.4
#   Median length: 100.0
#   Min length: 1
#   Max length: 17532
#   Size: 186 documents
#
# Cluster 7:
#   Mean length: 97.1
#   Median length: 18.0
#   Min length: 1
#   Max length: 2669
#   Size: 57 documents
#
# Cluster 8:
#   Mean length: 49.1
#   Median length: 1.0
#   Min length: 1
#   Max length: 2011
#   Size: 42 documents
#
# Cluster 9:
#   Mean length: 61.7
#   Median length: 23.0
#   Min length: 2
#   Max length: 407
#   Size: 33 documents
#
# For k-means with 20 clusters:
#
# Cluster 0:
#   Mean length: 161.3
#   Median length: 40.5
#   Min length: 1
#   Max length: 6191
#   Size: 1024 documents
#
# Cluster 1:
#   Mean length: 1414.0
#   Median length: 642.0
#   Min length: 1
#   Max length: 21641
#   Size: 177 documents
#
# Cluster 2:
#   Mean length: 340.2
#   Median length: 55.0
#   Min length: 1
#   Max length: 4893
#   Size: 80 documents
#
# Cluster 3:
#   Mean length: 124.1
#   Median length: 37.5
#   Min length: 2
#   Max length: 778
#   Size: 38 documents
#
# Cluster 4:
#   Mean length: 1931.7
#   Median length: 1021.0
#   Min length: 1
#   Max length: 13412
#   Size: 171 documents
#
# Cluster 5:
#   Mean length: 99.9
#   Median length: 16.0
#   Min length: 1
#   Max length: 2669
#   Size: 51 documents
#
# Cluster 6:
#   Mean length: 111.5
#   Median length: 39.5
#   Min length: 1
#   Max length: 1351
#   Size: 48 documents
#
# Cluster 7:
#   Mean length: 1.5
#   Median length: 2.0
#   Min length: 1
#   Max length: 2
#   Size: 19 documents
#
# Cluster 8:
#   Mean length: 747.7
#   Median length: 37.0
#   Min length: 2
#   Max length: 6792
#   Size: 19 documents
#
# Cluster 9:
#   Mean length: 137.0
#   Median length: 30.0
#   Min length: 1
#   Max length: 1493
#   Size: 81 documents
#
# Cluster 10:
#   Mean length: 73.7
#   Median length: 27.0
#   Min length: 1
#   Max length: 898
#   Size: 30 documents
#
# Cluster 11:
#   Mean length: 798.3
#   Median length: 334.0
#   Min length: 1
#   Max length: 19397
#   Size: 540 documents
#
# Cluster 12:
#   Mean length: 1477.2
#   Median length: 704.0
#   Min length: 18
#   Max length: 5182
#   Size: 6 documents
#
# Cluster 13:
#   Mean length: 369.2
#   Median length: 78.0
#   Min length: 1
#   Max length: 17532
#   Size: 159 documents
#
# Cluster 14:
#   Mean length: 81.8
#   Median length: 18.0
#   Min length: 1
#   Max length: 647
#   Size: 33 documents
#
# Cluster 15:
#   Mean length: 271.5
#   Median length: 191.0
#   Min length: 12
#   Max length: 2086
#   Size: 43 documents
#
# Cluster 16:
#   Mean length: 88.4
#   Median length: 1.0
#   Min length: 1
#   Max length: 2011
#   Size: 23 documents
#
# Cluster 17:
#   Mean length: 38.5
#   Median length: 18.5
#   Min length: 2
#   Max length: 298
#   Size: 26 documents
#
# Cluster 18:
#   Mean length: 192.4
#   Median length: 50.5
#   Min length: 7
#   Max length: 2807
#   Size: 30 documents
#
# Cluster 19:
#   Mean length: 73.2
#   Median length: 59.0
#   Min length: 4
#   Max length: 256
#   Size: 32 documents
#
# For k-means with 30 clusters:
#
# Cluster 0:
#   Mean length: 163.4
#   Median length: 15.0
#   Min length: 2
#   Max length: 1452
#   Size: 15 documents
#
# Cluster 1:
#   Mean length: 1417.4
#   Median length: 642.0
#   Min length: 1
#   Max length: 21641
#   Size: 177 documents
#
# Cluster 2:
#   Mean length: 337.9
#   Median length: 58.0
#   Min length: 1
#   Max length: 4893
#   Size: 75 documents
#
# Cluster 3:
#   Mean length: 84.9
#   Median length: 42.0
#   Min length: 2
#   Max length: 924
#   Size: 25 documents
#
# Cluster 4:
#   Mean length: 104.2
#   Median length: 23.0
#   Min length: 1
#   Max length: 1803
#   Size: 32 documents
#
# Cluster 5:
#   Mean length: 570.8
#   Median length: 223.0
#   Min length: 2
#   Max length: 19397
#   Size: 565 documents
#
# Cluster 6:
#   Mean length: 108.2
#   Median length: 27.0
#   Min length: 2
#   Max length: 1493
#   Size: 51 documents
#
# Cluster 7:
#   Mean length: 254.7
#   Median length: 21.5
#   Min length: 1
#   Max length: 8494
#   Size: 48 documents
#
# Cluster 8:
#   Mean length: 1676.4
#   Median length: 1355.0
#   Min length: 18
#   Max length: 5182
#   Size: 7 documents
#
# Cluster 9:
#   Mean length: 1674.1
#   Median length: 1415.0
#   Min length: 1
#   Max length: 10229
#   Size: 69 documents
#
# Cluster 10:
#   Mean length: 1727.5
#   Median length: 891.0
#   Min length: 1
#   Max length: 13412
#   Size: 175 documents
#
# Cluster 11:
#   Mean length: 243.3
#   Median length: 161.0
#   Min length: 16
#   Max length: 2086
#   Size: 25 documents
#
# Cluster 12:
#   Mean length: 37.3
#   Median length: 18.5
#   Min length: 1
#   Max length: 298
#   Size: 20 documents
#
# Cluster 13:
#   Mean length: 370.5
#   Median length: 43.0
#   Min length: 1
#   Max length: 17532
#   Size: 105 documents
#
# Cluster 14:
#   Mean length: 147.4
#   Median length: 27.0
#   Min length: 1
#   Max length: 2283
#   Size: 79 documents
#
# Cluster 15:
#   Mean length: 53.8
#   Median length: 17.0
#   Min length: 1
#   Max length: 300
#   Size: 19 documents
#
# Cluster 16:
#   Mean length: 25.5
#   Median length: 18.0
#   Min length: 2
#   Max length: 85
#   Size: 21 documents
#
# Cluster 17:
#   Mean length: 26.5
#   Median length: 16.0
#   Min length: 1
#   Max length: 177
#   Size: 29 documents
#
# Cluster 18:
#   Mean length: 52.3
#   Median length: 28.0
#   Min length: 2
#   Max length: 323
#   Size: 48 documents
#
# Cluster 19:
#   Mean length: 1007.6
#   Median length: 475.0
#   Min length: 20
#   Max length: 17956
#   Size: 59 documents
#
# Cluster 20:
#   Mean length: 42.6
#   Median length: 16.0
#   Min length: 1
#   Max length: 311
#   Size: 21 documents
#
# Cluster 21:
#   Mean length: 74.0
#   Median length: 63.5
#   Min length: 36
#   Max length: 212
#   Size: 22 documents
#
# Cluster 22:
#   Mean length: 90.0
#   Median length: 36.0
#   Min length: 2
#   Max length: 1548
#   Size: 37 documents
#
# Cluster 23:
#   Mean length: 64.1
#   Median length: 1.0
#   Min length: 1
#   Max length: 2011
#   Size: 32 documents
#
# Cluster 24:
#   Mean length: 184.6
#   Median length: 43.0
#   Min length: 1
#   Max length: 3446
#   Size: 50 documents
#
# Cluster 25:
#   Mean length: 265.2
#   Median length: 139.0
#   Min length: 9
#   Max length: 2440
#   Size: 65 documents
#
# Cluster 26:
#   Mean length: 281.0
#   Median length: 21.0
#   Min length: 1
#   Max length: 3672
#   Size: 54 documents
#
# Cluster 27:
#   Mean length: 147.9
#   Median length: 37.5
#   Min length: 1
#   Max length: 3501
#   Size: 684 documents
#
# Cluster 28:
#   Mean length: 1288.5
#   Median length: 248.5
#   Min length: 17
#   Max length: 6792
#   Size: 8 documents
#
# Cluster 29:
#   Mean length: 246.0
#   Median length: 194.0
#   Min length: 27
#   Max length: 691
#   Size: 13 documents
#
# For k-means with 40 clusters:
#
# Cluster 0:
#   Mean length: 1762.6
#   Median length: 1355.0
#   Min length: 18
#   Max length: 5182
#   Size: 5 documents
#
# Cluster 1:
#   Mean length: 493.6
#   Median length: 59.0
#   Min length: 1
#   Max length: 17532
#   Size: 101 documents
#
# Cluster 2:
#   Mean length: 185.4
#   Median length: 40.0
#   Min length: 3
#   Max length: 2116
#   Size: 31 documents
#
# Cluster 3:
#   Mean length: 153.8
#   Median length: 38.0
#   Min length: 1
#   Max length: 1355
#   Size: 43 documents
#
# Cluster 4:
#   Mean length: 87.6
#   Median length: 20.0
#   Min length: 1
#   Max length: 504
#   Size: 32 documents
#
# Cluster 5:
#   Mean length: 345.7
#   Median length: 23.0
#   Min length: 1
#   Max length: 2521
#   Size: 23 documents
#
# Cluster 6:
#   Mean length: 186.3
#   Median length: 67.5
#   Min length: 3
#   Max length: 1103
#   Size: 28 documents
#
# Cluster 7:
#   Mean length: 1301.0
#   Median length: 596.0
#   Min length: 1
#   Max length: 21641
#   Size: 196 documents
#
# Cluster 8:
#   Mean length: 58.8
#   Median length: 18.5
#   Min length: 2
#   Max length: 300
#   Size: 22 documents
#
# Cluster 9:
#   Mean length: 132.3
#   Median length: 53.0
#   Min length: 5
#   Max length: 847
#   Size: 19 documents
#
# Cluster 10:
#   Mean length: 523.1
#   Median length: 37.0
#   Min length: 1
#   Max length: 6792
#   Size: 25 documents
#
# Cluster 11:
#   Mean length: 282.6
#   Median length: 202.0
#   Min length: 16
#   Max length: 2086
#   Size: 35 documents
#
# Cluster 12:
#   Mean length: 143.3
#   Median length: 40.5
#   Min length: 2
#   Max length: 1755
#   Size: 78 documents
#
# Cluster 13:
#   Mean length: 1695.2
#   Median length: 784.0
#   Min length: 1
#   Max length: 13412
#   Size: 153 documents
#
# Cluster 14:
#   Mean length: 441.0
#   Median length: 185.0
#   Min length: 12
#   Max length: 5820
#   Size: 59 documents
#
# Cluster 15:
#   Mean length: 267.9
#   Median length: 26.0
#   Min length: 7
#   Max length: 3298
#   Size: 32 documents
#
# Cluster 16:
#   Mean length: 59.4
#   Median length: 30.0
#   Min length: 2
#   Max length: 233
#   Size: 13 documents
#
# Cluster 17:
#   Mean length: 167.8
#   Median length: 31.0
#   Min length: 1
#   Max length: 1386
#   Size: 17 documents
#
# Cluster 18:
#   Mean length: 147.5
#   Median length: 36.0
#   Min length: 1
#   Max length: 6191
#   Size: 525 documents
#
# Cluster 19:
#   Mean length: 1189.7
#   Median length: 276.5
#   Min length: 13
#   Max length: 19397
#   Size: 40 documents
#
# Cluster 20:
#   Mean length: 239.3
#   Median length: 71.0
#   Min length: 2
#   Max length: 2807
#   Size: 33 documents
#
# Cluster 21:
#   Mean length: 83.5
#   Median length: 16.0
#   Min length: 4
#   Max length: 1007
#   Size: 31 documents
#
# Cluster 22:
#   Mean length: 38.7
#   Median length: 27.5
#   Min length: 2
#   Max length: 205
#   Size: 18 documents
#
# Cluster 23:
#   Mean length: 524.9
#   Median length: 72.5
#   Min length: 1
#   Max length: 8494
#   Size: 48 documents
#
# Cluster 24:
#   Mean length: 229.9
#   Median length: 25.0
#   Min length: 1
#   Max length: 1676
#   Size: 39 documents
#
# Cluster 25:
#   Mean length: 86.9
#   Median length: 30.5
#   Min length: 4
#   Max length: 353
#   Size: 10 documents
#
# Cluster 26:
#   Mean length: 100.6
#   Median length: 38.0
#   Min length: 1
#   Max length: 855
#   Size: 59 documents
#
# Cluster 27:
#   Mean length: 349.5
#   Median length: 111.5
#   Min length: 1
#   Max length: 4762
#   Size: 102 documents
#
# Cluster 28:
#   Mean length: 2151.1
#   Median length: 1950.0
#   Min length: 203
#   Max length: 10229
#   Size: 51 documents
#
# Cluster 29:
#   Mean length: 54.5
#   Median length: 30.0
#   Min length: 3
#   Max length: 323
#   Size: 43 documents
#
# Cluster 30:
#   Mean length: 1.5
#   Median length: 2.0
#   Min length: 1
#   Max length: 2
#   Size: 19 documents
#
# Cluster 31:
#   Mean length: 75.1
#   Median length: 60.0
#   Min length: 14
#   Max length: 256
#   Size: 23 documents
#
# Cluster 32:
#   Mean length: 200.0
#   Median length: 57.0
#   Min length: 1
#   Max length: 3946
#   Size: 81 documents
#
# Cluster 33:
#   Mean length: 202.1
#   Median length: 89.0
#   Min length: 6
#   Max length: 765
#   Size: 19 documents
#
# Cluster 34:
#   Mean length: 752.5
#   Median length: 324.0
#   Min length: 6
#   Max length: 5478
#   Size: 154 documents
#
# Cluster 35:
#   Mean length: 51.9
#   Median length: 15.5
#   Min length: 1
#   Max length: 404
#   Size: 40 documents
#
# Cluster 36:
#   Mean length: 251.5
#   Median length: 165.5
#   Min length: 5
#   Max length: 1084
#   Size: 24 documents
#
# Cluster 37:
#   Mean length: 88.4
#   Median length: 1.0
#   Min length: 1
#   Max length: 2011
#   Size: 23 documents
#
# Cluster 38:
#   Mean length: 89.4
#   Median length: 28.0
#   Min length: 2
#   Max length: 924
#   Size: 25 documents
#
# Cluster 39:
#   Mean length: 602.5
#   Median length: 287.0
#   Min length: 1
#   Max length: 17956
#   Size: 311 documents
#
# For k-means with 50 clusters:
#
# Cluster 0:
#   Mean length: 120.8
#   Median length: 21.0
#   Min length: 1
#   Max length: 1548
#   Size: 29 documents
#
# Cluster 1:
#   Mean length: 104.0
#   Median length: 27.5
#   Min length: 1
#   Max length: 620
#   Size: 22 documents
#
# Cluster 2:
#   Mean length: 159.9
#   Median length: 131.0
#   Min length: 3
#   Max length: 421
#   Size: 13 documents
#
# Cluster 3:
#   Mean length: 47.2
#   Median length: 22.5
#   Min length: 1
#   Max length: 376
#   Size: 30 documents
#
# Cluster 4:
#   Mean length: 217.8
#   Median length: 76.0
#   Min length: 2
#   Max length: 2699
#   Size: 45 documents
#
# Cluster 5:
#   Mean length: 114.9
#   Median length: 50.0
#   Min length: 1
#   Max length: 969
#   Size: 76 documents
#
# Cluster 6:
#   Mean length: 789.7
#   Median length: 341.0
#   Min length: 1
#   Max length: 6933
#   Size: 59 documents
#
# Cluster 7:
#   Mean length: 331.6
#   Median length: 110.0
#   Min length: 3
#   Max length: 4451
#   Size: 29 documents
#
# Cluster 8:
#   Mean length: 343.0
#   Median length: 58.0
#   Min length: 1
#   Max length: 4893
#   Size: 70 documents
#
# Cluster 9:
#   Mean length: 105.7
#   Median length: 31.0
#   Min length: 2
#   Max length: 1845
#   Size: 57 documents
#
# Cluster 10:
#   Mean length: 1.5
#   Median length: 2.0
#   Min length: 1
#   Max length: 2
#   Size: 19 documents
#
# Cluster 11:
#   Mean length: 33.4
#   Median length: 14.0
#   Min length: 3
#   Max length: 196
#   Size: 20 documents
#
# Cluster 12:
#   Mean length: 98.3
#   Median length: 63.5
#   Min length: 2
#   Max length: 564
#   Size: 56 documents
#
# Cluster 13:
#   Mean length: 104.1
#   Median length: 9.0
#   Min length: 2
#   Max length: 407
#   Size: 8 documents
#
# Cluster 14:
#   Mean length: 88.4
#   Median length: 1.0
#   Min length: 1
#   Max length: 2011
#   Size: 23 documents
#
# Cluster 15:
#   Mean length: 191.2
#   Median length: 24.0
#   Min length: 6
#   Max length: 1289
#   Size: 12 documents
#
# Cluster 16:
#   Mean length: 231.7
#   Median length: 15.0
#   Min length: 4
#   Max length: 1444
#   Size: 19 documents
#
# Cluster 17:
#   Mean length: 1717.5
#   Median length: 1846.0
#   Min length: 10
#   Max length: 4192
#   Size: 23 documents
#
# Cluster 18:
#   Mean length: 658.4
#   Median length: 25.0
#   Min length: 2
#   Max length: 3672
#   Size: 30 documents
#
# Cluster 19:
#   Mean length: 49.0
#   Median length: 16.0
#   Min length: 1
#   Max length: 404
#   Size: 23 documents
#
# Cluster 20:
#   Mean length: 483.0
#   Median length: 74.0
#   Min length: 5
#   Max length: 2807
#   Size: 10 documents
#
# Cluster 21:
#   Mean length: 204.1
#   Median length: 48.0
#   Min length: 2
#   Max length: 1109
#   Size: 19 documents
#
# Cluster 22:
#   Mean length: 322.1
#   Median length: 57.0
#   Min length: 1
#   Max length: 6912
#   Size: 98 documents
#
# Cluster 23:
#   Mean length: 113.7
#   Median length: 30.0
#   Min length: 2
#   Max length: 1355
#   Size: 37 documents
#
# Cluster 24:
#   Mean length: 65.4
#   Median length: 26.0
#   Min length: 1
#   Max length: 352
#   Size: 25 documents
#
# Cluster 25:
#   Mean length: 474.7
#   Median length: 284.0
#   Min length: 7
#   Max length: 2098
#   Size: 29 documents
#
# Cluster 26:
#   Mean length: 45.1
#   Median length: 21.0
#   Min length: 1
#   Max length: 300
#   Size: 29 documents
#
# Cluster 27:
#   Mean length: 79.5
#   Median length: 40.5
#   Min length: 2
#   Max length: 331
#   Size: 20 documents
#
# Cluster 28:
#   Mean length: 1187.6
#   Median length: 644.0
#   Min length: 1
#   Max length: 10163
#   Size: 291 documents
#
# Cluster 29:
#   Mean length: 297.5
#   Median length: 89.0
#   Min length: 1
#   Max length: 19397
#   Size: 784 documents
#
# Cluster 30:
#   Mean length: 50.0
#   Median length: 15.0
#   Min length: 1
#   Max length: 369
#   Size: 21 documents
#
# Cluster 31:
#   Mean length: 273.3
#   Median length: 63.0
#   Min length: 1
#   Max length: 3086
#   Size: 54 documents
#
# Cluster 32:
#   Mean length: 136.5
#   Median length: 24.5
#   Min length: 2
#   Max length: 1493
#   Size: 24 documents
#
# Cluster 33:
#   Mean length: 231.2
#   Median length: 70.0
#   Min length: 1
#   Max length: 1691
#   Size: 31 documents
#
# Cluster 34:
#   Mean length: 278.6
#   Median length: 203.0
#   Min length: 16
#   Max length: 2086
#   Size: 37 documents
#
# Cluster 35:
#   Mean length: 1704.4
#   Median length: 452.0
#   Min length: 20
#   Max length: 8494
#   Size: 12 documents
#
# Cluster 36:
#   Mean length: 1253.6
#   Median length: 815.0
#   Min length: 100
#   Max length: 4466
#   Size: 7 documents
#
# Cluster 37:
#   Mean length: 1679.9
#   Median length: 731.0
#   Min length: 60
#   Max length: 21641
#   Size: 165 documents
#
# Cluster 38:
#   Mean length: 1736.0
#   Median length: 78.0
#   Min length: 3
#   Max length: 17956
#   Size: 23 documents
#
# Cluster 39:
#   Mean length: 96.0
#   Median length: 36.0
#   Min length: 2
#   Max length: 855
#   Size: 29 documents
#
# Cluster 40:
#   Mean length: 20.4
#   Median length: 18.5
#   Min length: 7
#   Max length: 46
#   Size: 8 documents
#
# Cluster 41:
#   Mean length: 106.3
#   Median length: 7.0
#   Min length: 1
#   Max length: 898
#   Size: 11 documents
#
# Cluster 42:
#   Mean length: 2125.9
#   Median length: 1696.5
#   Min length: 118
#   Max length: 10229
#   Size: 42 documents
#
# Cluster 43:
#   Mean length: 311.2
#   Median length: 218.0
#   Min length: 2
#   Max length: 2116
#   Size: 13 documents
#
# Cluster 44:
#   Mean length: 430.8
#   Median length: 98.0
#   Min length: 3
#   Max length: 5820
#   Size: 35 documents
#
# Cluster 45:
#   Mean length: 92.5
#   Median length: 39.0
#   Min length: 7
#   Max length: 924
#   Size: 19 documents
#
# Cluster 46:
#   Mean length: 107.5
#   Median length: 13.0
#   Min length: 1
#   Max length: 1358
#   Size: 22 documents
#
# Cluster 47:
#   Mean length: 202.2
#   Median length: 33.0
#   Min length: 2
#   Max length: 1221
#   Size: 9 documents
#
# Cluster 48:
#   Mean length: 48.3
#   Median length: 30.0
#   Min length: 5
#   Max length: 217
#   Size: 35 documents
#
# Cluster 49:
#   Mean length: 176.8
#   Median length: 24.0
#   Min length: 7
#   Max length: 2440
#   Size: 28 documents

# %%
# save_topk_words("../topk/tfidf/tfidf", df, kms, 25, (10, 51, 1), True)

# %%
# def save_topk_words(df, km, nc, k):
#     text_buffer = ""
#     cluster_words = []
#     for i in range(km.n_clusters):
#         cluster_mask = km.labels_ == i
#         cluster_docs = df[cluster_mask]["transcript"].tolist()

#         words = " ".join(cluster_docs).split()
#         wc = Counter(words)
#         top_words = wc.most_common(k)
#         cluster_words.append(top_words)

#         text_buffer += f"\nCluster {i} top {k} words:\n"
#         for w, c in top_words:
#             text_buffer += f"{w}: {c}\n"
        
#     with open(f"topk/baseline_tfidf_{nc}_{k}.txt", "+w") as f:
#         f.write(text_buffer)

# %%
# for nc in range(10, 20):
#     idx = nc-10
#     save_topk_words(df, kms[idx], nc, 25)
